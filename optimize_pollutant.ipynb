# %%
# %load_ext autoreload
# %autoreload 2

# %%
from src.SWATPollution import SWATPollution
from src.SWATPollutionOptimizer import SWATPollutionOptimizer
from pathlib import Path
# Out:
# c:\Users\jsalo\anaconda3\envs\pySWAT\lib\site-packages\geoviews\operation\__init__.py:14: HoloviewsDeprecationWarning: 'ResamplingOperation' is deprecated and will be removed in version 1.18, use 'ResampleOperation2D' instead.
#   from holoviews.operation.datashader import (
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#   <img src='...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
# </div>
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\jsalo\Desktop\ICRA\traca_contaminacio\traca_contaminacio\optimize_pollutant.ipynb Cell 2 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/jsalo/Desktop/ICRA/traca_contaminacio/traca_contaminacio/optimize_pollutant.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> from src.SWATPollution import SWATPollution
# ----> <a href='vscode-notebook-cell:/c%3A/Users/jsalo/Desktop/ICRA/traca_contaminacio/traca_contaminacio/optimize_pollutant.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> from src.SWATPollutionOptimizer import SWATPollutionOptimizer
#       <a href='vscode-notebook-cell:/c%3A/Users/jsalo/Desktop/ICRA/traca_contaminacio/traca_contaminacio/optimize_pollutant.ipynb#W1sZmlsZQ%3D%3D?line=2'>3</a> from pathlib import Path
#
# File c:\Users\jsalo\Desktop\ICRA\traca_contaminacio\traca_contaminacio\src\SWATPollutionOptimizer.py:14
#      11 from pymoo.util.normalization import denormalize
#      12 from src.pollution_utils import observacions_from_conca
# ---> 14 from pySWATPlus.SWATProblem import SWATProblem, minimize_pymoo
#      19 def wrapper_get_error_pollution_generation(dict_args):
#      20     return get_error_pollution_generation(**dict_args)
#
# File c:\Users\jsalo\anaconda3\envs\pySWAT\lib\site-packages\pySWATPlus\SWATProblem.py:8
#       6 import numpy as np
#       7 from typing import Optional, Callable, Tuple, Any, Dict, List
# ----> 8 from pymoo.model.algorithm import Algorithm
#       9 from pymoo.model.termination import Termination
#      11 def minimize_pymoo(
#      12         problem: Problem,
#      13         algorithm: Algorithm,
#    (...)
#      16         verbose: bool = False,
#      17         callback: Optional[Callable] = None) -> Tuple[Optional[np.ndarray], Optional[str], Optional[float]]:
#
# ModuleNotFoundError: No module named 'pymoo.model'

# %%
contaminant = 'Diuron'
conca = 'fluvia'

# %%
cwd = Path('/mnt/c/Users/jsalo/Desktop/ICRA/pyswat')

a = SWATPollutionOptimizer(
    conca, 
    contaminant, 
    txtinout_folder = cwd/'data'/'txtinouts'/f"TxtInOut_{conca}",
    channels_geom_path = cwd/'data'/'rivs1'/'canals_tot_ci.shp',
    tmp_path = cwd/'data'/'txtinouts'/'tmp',
    compound_features_path = cwd/'data'/'compound_features.xlsx',
    lb_factor = 0.2,
    ub_factor = 0.5
)

# %%
res = a.minimize()
# Out:
# simulation started
# simulation ended
# error en simulacio:  0.13436424411240122
# simulation started
# simulation ended
# error en simulacio:  0.8474337369372327
# simulation started
# simulation ended
# error en simulacio:  0.763774618976614
# simulation started
# simulation ended
# error en simulacio:  0.2550690257394217
# =================================================
# n_gen  |  n_eval  |     f_avg     |     f_min
# =================================================
#      1 |        4 |  0.5001604064 |  0.1343642441
# simulation started
# simulation ended
# error en simulacio:  0.49543508709194095
# simulation started
# simulation ended
# error en simulacio:  0.4494910647887381
# simulation started
# simulation ended
# error en simulacio:  0.651592972722763
# simulation started
# simulation ended
# error en simulacio:  0.7887233511355132
#      2 |        8 |  0.3335898554 |  0.1343642441
# simulation started
# simulation ended
# error en simulacio:  0.0938595867742349
# simulation started
# simulation ended
# error en simulacio:  0.02834747652200631
# simulation started
# simulation ended
# error en simulacio:  0.8357651039198697
# simulation started
# simulation ended
# error en simulacio:  0.43276706790505337
#      3 |       12 |  0.1279100833 |  0.0283474765
# simulation started
# simulation ended
# error en simulacio:  0.762280082457942
# simulation started
# simulation ended
# error en simulacio:  0.0021060533511106927
# simulation started
# simulation ended
# error en simulacio:  0.4453871940548014
# simulation started
# simulation ended
# error en simulacio:  0.7215400323407826
#      4 |       16 |  0.0646693402 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.22876222127045265
# simulation started
# simulation ended
# error en simulacio:  0.9452706955539223
# simulation started
# simulation ended
# error en simulacio:  0.9014274576114836
# simulation started
# simulation ended
# error en simulacio:  0.030589983033553536
#      5 |       20 |  0.0387257749 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.0254458609934608
# simulation started
# simulation ended
# error en simulacio:  0.5414124727934966
# simulation started
# simulation ended
# error en simulacio:  0.9391491627785106
# simulation started
# simulation ended
# error en simulacio:  0.38120423768821243
#      6 |       24 |  0.0216223435 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.21659939713061338
# simulation started
# simulation ended
# error en simulacio:  0.4221165755827173
# simulation started
# simulation ended
# error en simulacio:  0.029040787574867943
# simulation started
# simulation ended
# error en simulacio:  0.22169166627303505
#      7 |       28 |  0.0212350446 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.43788759365057206
# simulation started
# simulation ended
# error en simulacio:  0.49581224138185065
# simulation started
# simulation ended
# error en simulacio:  0.23308445025757263
# simulation started
# simulation ended
# error en simulacio:  0.2308665415409843
#      8 |       32 |  0.0212350446 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.2187810373376886
# simulation started
# simulation ended
# error en simulacio:  0.4596034657377336
# simulation started
# simulation ended
# error en simulacio:  0.28978161459048557
# simulation started
# simulation ended
# error en simulacio:  0.021489705265908876
#      9 |       36 |  0.0193472740 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.8375779756625729
# simulation started
# simulation ended
# error en simulacio:  0.5564543226524334
# simulation started
# simulation ended
# error en simulacio:  0.6422943629324456
# simulation started
# simulation ended
# error en simulacio:  0.1859062658947177
#     10 |       40 |  0.0193472740 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.9925434121760651
# simulation started
# simulation ended
# error en simulacio:  0.8599465287952899
# simulation started
# simulation ended
# error en simulacio:  0.12088995980580641
# simulation started
# simulation ended
# error en simulacio:  0.3326951853601291
#     11 |       44 |  0.0193472740 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.7214844075832684
# simulation started
# simulation ended
# error en simulacio:  0.7111917696952796
# simulation started
# simulation ended
# error en simulacio:  0.9364405867994596
# simulation started
# simulation ended
# error en simulacio:  0.4221069999614152
#     12 |       48 |  0.0193472740 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.830035693274327
# simulation started
# simulation ended
# error en simulacio:  0.670305566414071
# simulation started
# simulation ended
# error en simulacio:  0.3033685109329176
# simulation started
# simulation ended
# error en simulacio:  0.5875806061435594
#     13 |       52 |  0.0193472740 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.8824790008318577
# simulation started
# simulation ended
# error en simulacio:  0.8461974184283128
# simulation started
# simulation ended
# error en simulacio:  0.5052838205796004
# simulation started
# simulation ended
# error en simulacio:  0.5890022579825517
#     14 |       56 |  0.0193472740 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.034525830151341586
# simulation started
# simulation ended
# error en simulacio:  0.24273997354306764
# simulation started
# simulation ended
# error en simulacio:  0.7974042475543028
# simulation started
# simulation ended
# error en simulacio:  0.4143139993007743
#     15 |       60 |  0.0193472740 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.17300740157905092
# simulation started
# simulation ended
# error en simulacio:  0.548798761388153
# simulation started
# simulation ended
# error en simulacio:  0.7030407620656315
# simulation started
# simulation ended
# error en simulacio:  0.6744858305023272
#     16 |       64 |  0.0193472740 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.3747030205016403
# simulation started
# simulation ended
# error en simulacio:  0.4389616300445631
# simulation started
# simulation ended
# error en simulacio:  0.5084264882499818
# simulation started
# simulation ended
# error en simulacio:  0.7784426150001458
#     17 |       68 |  0.0193472740 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.5209384176131452
# simulation started
# simulation ended
# error en simulacio:  0.39325509496422606
# simulation started
# simulation ended
# error en simulacio:  0.4896935204622582
# simulation started
# simulation ended
# error en simulacio:  0.029574963966907064
#     18 |       72 |  0.0193472740 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.04348729035652743
# simulation started
# simulation ended
# error en simulacio:  0.703382088603836
# simulation started
# simulation ended
# error en simulacio:  0.9831877173096739
# simulation started
# simulation ended
# error en simulacio:  0.5931837303800576
#     19 |       76 |  0.0193472740 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.393599686377914
# simulation started
# simulation ended
# error en simulacio:  0.17034919685568128
# simulation started
# simulation ended
# error en simulacio:  0.5022385584334831
# simulation started
# simulation ended
# error en simulacio:  0.9820766375385342
#     20 |       80 |  0.0193472740 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.7705231398308006
# simulation started
# simulation ended
# error en simulacio:  0.5396174484497788
# simulation started
# simulation ended
# error en simulacio:  0.8602897789205496
# simulation started
# simulation ended
# error en simulacio:  0.23217612806301458
#     21 |       84 |  0.0193472740 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.513771663187637
# simulation started
# simulation ended
# error en simulacio:  0.9524673882682695
# simulation started
# simulation ended
# error en simulacio:  0.5777948078012031
# simulation started
# simulation ended
# error en simulacio:  0.45913173191066836
#     22 |       88 |  0.0193472740 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.2692794774414212
# simulation started
# simulation ended
# error en simulacio:  0.5479963094662489
# simulation started
# simulation ended
# error en simulacio:  0.9571162814602269
# simulation started
# simulation ended
# error en simulacio:  0.005709129450392925
#     23 |       92 |  0.0136876873 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.7836552326153898
# simulation started
# simulation ended
# error en simulacio:  0.8204859119254819
# simulation started
# simulation ended
# error en simulacio:  0.8861795808260082
# simulation started
# simulation ended
# error en simulacio:  0.7405034118331963
#     24 |       96 |  0.0136876873 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.8091399008724796
# simulation started
# simulation ended
# error en simulacio:  0.518678283523002
# simulation started
# simulation ended
# error en simulacio:  0.561357864778379
# simulation started
# simulation ended
# error en simulacio:  0.4260906796881502
#     25 |      100 |  0.0136876873 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.05612329752074041
# simulation started
# simulation ended
# error en simulacio:  0.8700101551766398
# simulation started
# simulation ended
# error en simulacio:  0.5699993338763802
# simulation started
# simulation ended
# error en simulacio:  0.19983942017714307
#     26 |      104 |  0.0136876873 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.5047204674288633
# simulation started
# simulation ended
# error en simulacio:  0.48492511222773416
# simulation started
# simulation ended
# error en simulacio:  0.3567899645449557
# simulation started
# simulation ended
# error en simulacio:  0.3460779190181549
#     27 |      108 |  0.0136876873 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.5384787957378443
# simulation started
# simulation ended
# error en simulacio:  0.6234894527975051
# simulation started
# simulation ended
# error en simulacio:  0.6124524647827256
# simulation started
# simulation ended
# error en simulacio:  0.4581468000997244
#     28 |      112 |  0.0136876873 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.027974984083842358
# simulation started
# simulation ended
# error en simulacio:  0.22960503127702392
# simulation started
# simulation ended
# error en simulacio:  0.1772112589385827
# simulation started
# simulation ended
# error en simulacio:  0.5844608707784413
#     29 |      116 |  0.0136876873 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.8610088608533248
# simulation started
# simulation ended
# error en simulacio:  0.798438940577426
# simulation started
# simulation ended
# error en simulacio:  0.7970975626354962
# simulation started
# simulation ended
# error en simulacio:  0.8164373705606909
#     30 |      120 |  0.0136876873 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.25529404008730594
# simulation started
# simulation ended
# error en simulacio:  0.841744832274096
# simulation started
# simulation ended
# error en simulacio:  0.6731135254387071
# simulation started
# simulation ended
# error en simulacio:  0.08323413780389788
#     31 |      124 |  0.0136876873 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.0166906301155596
# simulation started
# simulation ended
# error en simulacio:  0.014559974924812313
# simulation started
# simulation ended
# error en simulacio:  0.7555867752521982
# simulation started
# simulation ended
# error en simulacio:  0.2495592256534228
#     32 |      128 |  0.0097664470 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.10948862729435938
# simulation started
# simulation ended
# error en simulacio:  0.6248020841524763
# simulation started
# simulation ended
# error en simulacio:  0.3444228640964949
# simulation started
# simulation ended
# error en simulacio:  0.06951537853084733
#     33 |      132 |  0.0097664470 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.1596255246938475
# simulation started
# simulation ended
# error en simulacio:  0.5273803990480128
# simulation started
# simulation ended
# error en simulacio:  0.16814494622242826
# simulation started
# simulation ended
# error en simulacio:  0.2729144368186801
#     34 |      136 |  0.0097664470 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.7115899271852729
# simulation started
# simulation ended
# error en simulacio:  0.4547016300456639
# simulation started
# simulation ended
# error en simulacio:  0.3220017663873259
# simulation started
# simulation ended
# error en simulacio:  0.4737710141702789
#     35 |      140 |  0.0097664470 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.023634577631987064
# simulation started
# simulation ended
# error en simulacio:  0.38655710476146987
# simulation started
# simulation ended
# error en simulacio:  0.4209186792090759
# simulation started
# simulation ended
# error en simulacio:  0.18803930475131292
#     36 |      144 |  0.0097664470 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.10876169244541334
# simulation started
# simulation ended
# error en simulacio:  0.8998185003560202
# simulation started
# simulation ended
# error en simulacio:  0.5101159809286764
# simulation started
# simulation ended
# error en simulacio:  0.2090909925517701
#     37 |      148 |  0.0097664470 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.6056486400340165
# simulation started
# simulation ended
# error en simulacio:  0.8170396683778869
# simulation started
# simulation ended
# error en simulacio:  0.020818108509287336
# simulation started
# simulation ended
# error en simulacio:  0.017864520827795327
#     38 |      152 |  0.0097664470 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.146461740399346
# simulation started
# simulation ended
# error en simulacio:  0.7188354727617898
# simulation started
# simulation ended
# error en simulacio:  0.16022759262970465
# simulation started
# simulation ended
# error en simulacio:  0.7046056278520025
#     39 |      156 |  0.0097664470 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.6781757952769475
# simulation started
# simulation ended
# error en simulacio:  0.5447021635789044
# simulation started
# simulation ended
# error en simulacio:  0.22059974802267657
# simulation started
# simulation ended
# error en simulacio:  0.9755945178178834
#     40 |      160 |  0.0097664470 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.797810857706151
# simulation started
# simulation ended
# error en simulacio:  0.516599516949393
# simulation started
# simulation ended
# error en simulacio:  0.22319578024667075
# simulation started
# simulation ended
# error en simulacio:  0.6485064180992564
#     41 |      164 |  0.0097664470 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.3948980098582996
# simulation started
# simulation ended
# error en simulacio:  0.5758459627880567
# simulation started
# simulation ended
# error en simulacio:  0.32124580934512525
# simulation started
# simulation ended
# error en simulacio:  0.6309478612713469
#     42 |      168 |  0.0097664470 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.058785116206491295
# simulation started
# simulation ended
# error en simulacio:  0.29860594962301334
# simulation started
# simulation ended
# error en simulacio:  0.9679033101508892
# simulation started
# simulation ended
# error en simulacio:  0.8755342442351592
#     43 |      172 |  0.0097664470 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.30638662033324593
# simulation started
# simulation ended
# error en simulacio:  0.8585144063565593
# simulation started
# simulation ended
# error en simulacio:  0.31036362735313405
# simulation started
# simulation ended
# error en simulacio:  0.9392884321352825
#     44 |      176 |  0.0097664470 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.7438421186671211
# simulation started
# simulation ended
# error en simulacio:  0.4161722627650255
# simulation started
# simulation ended
# error en simulacio:  0.25235810227983535
# simulation started
# simulation ended
# error en simulacio:  0.008480262463668842
#     45 |      180 |  0.0077138550 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.8787178982088466
# simulation started
# simulation ended
# error en simulacio:  0.03791653059858058
# simulation started
# simulation ended
# error en simulacio:  0.8194141106127972
# simulation started
# simulation ended
# error en simulacio:  0.962201125180818
#     46 |      184 |  0.0077138550 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.5702805702451802
# simulation started
# simulation ended
# error en simulacio:  0.17151709517771863
# simulation started
# simulation ended
# error en simulacio:  0.8677810644349934
# simulation started
# simulation ended
# error en simulacio:  0.9737752361596916
#     47 |      188 |  0.0077138550 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.7040231423300713
# simulation started
# simulation ended
# error en simulacio:  0.5088737460778905
# simulation started
# simulation ended
# error en simulacio:  0.37796883434360806
# simulation started
# simulation ended
# error en simulacio:  0.34693088456262167
#     48 |      192 |  0.0077138550 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.2057617572947047
# simulation started
# simulation ended
# error en simulacio:  0.6741530142468641
# simulation started
# simulation ended
# error en simulacio:  0.4329501211003163
# simulation started
# simulation ended
# error en simulacio:  0.1941186449851896
#     49 |      196 |  0.0077138550 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.10442422284151531
# simulation started
# simulation ended
# error en simulacio:  0.6659575282786826
# simulation started
# simulation ended
# error en simulacio:  0.29607267308315155
# simulation started
# simulation ended
# error en simulacio:  0.4997999222368016
#     50 |      200 |  0.0077138550 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.3253456548759963
# simulation started
# simulation ended
# error en simulacio:  0.8716215074235552
# simulation started
# simulation ended
# error en simulacio:  0.8996782696347811
# simulation started
# simulation ended
# error en simulacio:  0.018092983640471738
#     51 |      204 |  0.0077138550 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.2008530114407594
# simulation started
# simulation ended
# error en simulacio:  0.3277407050962675
# simulation started
# simulation ended
# error en simulacio:  0.9870497179280261
# simulation started
# simulation ended
# error en simulacio:  0.7827003757293756
#     52 |      208 |  0.0077138550 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.3390956478509337
# simulation started
# simulation ended
# error en simulacio:  0.21302979638081376
# simulation started
# simulation ended
# error en simulacio:  0.6744550697237632
# simulation started
# simulation ended
# error en simulacio:  0.8377010701539643
#     53 |      212 |  0.0077138550 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.9321874718936273
# simulation started
# simulation ended
# error en simulacio:  0.3438498147908198
# simulation started
# simulation ended
# error en simulacio:  0.8823932024664636
# simulation started
# simulation ended
# error en simulacio:  0.6871101821536574
#     54 |      216 |  0.0077138550 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.48449872261249405
# simulation started
# simulation ended
# error en simulacio:  0.9855082298257978
# simulation started
# simulation ended
# error en simulacio:  0.23464043487103847
# simulation started
# simulation ended
# error en simulacio:  0.7254651862412724
#     55 |      220 |  0.0077138550 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.0846802304164842
# simulation started
# simulation ended
# error en simulacio:  0.16969414179438758
# simulation started
# simulation ended
# error en simulacio:  0.9109877835080679
# simulation started
# simulation ended
# error en simulacio:  0.21296819499142416
#     56 |      224 |  0.0077138550 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.7591161827164402
# simulation started
# simulation ended
# error en simulacio:  0.6002088301322496
# simulation started
# simulation ended
# error en simulacio:  0.8411321957058551
# simulation started
# simulation ended
# error en simulacio:  0.3681079994056491
#     57 |      228 |  0.0077138550 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.34028523500198804
# simulation started
# simulation ended
# error en simulacio:  0.29121528741113467
# simulation started
# simulation ended
# error en simulacio:  0.8674198235869027
# simulation started
# simulation ended
# error en simulacio:  0.6039825288917112
#     58 |      232 |  0.0077138550 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.9543074571721899
# simulation started
# simulation ended
# error en simulacio:  0.8872651047169627
# simulation started
# simulation ended
# error en simulacio:  0.13534597739545295
# simulation started
# simulation ended
# error en simulacio:  0.5511704740692165
#     59 |      236 |  0.0077138550 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.1042749980146136
# simulation started
# simulation ended
# error en simulacio:  0.03913779859691058
# simulation started
# simulation ended
# error en simulacio:  0.07319341883234853
# simulation started
# simulation ended
# error en simulacio:  0.866168357366572
#     60 |      240 |  0.0077138550 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.7881164487252263
# simulation started
# simulation ended
# error en simulacio:  0.8285059714691135
# simulation started
# simulation ended
# error en simulacio:  0.3408974641165834
# simulation started
# simulation ended
# error en simulacio:  0.6151860325590366
#     61 |      244 |  0.0077138550 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.7819036016327547
# simulation started
# simulation ended
# error en simulacio:  0.3780396288383874
# simulation started
# simulation ended
# error en simulacio:  0.5707815255990233
# simulation started
# simulation ended
# error en simulacio:  0.2237140727487692
#     62 |      248 |  0.0077138550 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.08174326235239371
# simulation started
# simulation ended
# error en simulacio:  0.26672364298173634
# simulation started
# simulation ended
# error en simulacio:  0.8907681278553053
# simulation started
# simulation ended
# error en simulacio:  0.5644468332401974
#     63 |      252 |  0.0077138550 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.9250672021084733
# simulation started
# simulation ended
# error en simulacio:  0.4577692590412453
# simulation started
# simulation ended
# error en simulacio:  0.2771827661076983
# simulation started
# simulation ended
# error en simulacio:  0.7870146635603288
#     64 |      256 |  0.0077138550 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.8277681566457297
# simulation started
# simulation ended
# error en simulacio:  0.012381744486666624
# simulation started
# simulation ended
# error en simulacio:  0.670411639023931
# simulation started
# simulation ended
# error en simulacio:  0.09168312261651779
#     65 |      260 |  0.0071692974 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.1151024984279273
# simulation started
# simulation ended
# error en simulacio:  0.8850600703796611
# simulation started
# simulation ended
# error en simulacio:  0.04002353689016469
# simulation started
# simulation ended
# error en simulacio:  0.2396333648675093
#     66 |      264 |  0.0071692974 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.9881584986060327
# simulation started
# simulation ended
# error en simulacio:  0.4210135874302673
# simulation started
# simulation ended
# error en simulacio:  0.1155581805922733
# simulation started
# simulation ended
# error en simulacio:  0.16738343746133177
#     67 |      268 |  0.0071692974 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.24142028509784308
# simulation started
# simulation ended
# error en simulacio:  0.7440064165370084
# simulation started
# simulation ended
# error en simulacio:  0.1028341459863098
# simulation started
# simulation ended
# error en simulacio:  0.9107644182793333
#     68 |      272 |  0.0071692974 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.3782772705442261
# simulation started
# simulation ended
# error en simulacio:  0.9702640365282106
# simulation started
# simulation ended
# error en simulacio:  0.9092227281507113
# simulation started
# simulation ended
# error en simulacio:  0.29402358494854774
#     69 |      276 |  0.0071692974 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.2534101360411267
# simulation started
# simulation ended
# error en simulacio:  0.47701009597226784
# simulation started
# simulation ended
# error en simulacio:  0.10012914395045203
# simulation started
# simulation ended
# error en simulacio:  0.6520501994894172
#     70 |      280 |  0.0071692974 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.039620213413704475
# simulation started
# simulation ended
# error en simulacio:  0.010506151518672291
# simulation started
# simulation ended
# error en simulacio:  0.9825836265504634
# simulation started
# simulation ended
# error en simulacio:  0.2955498600489178
#     71 |      284 |  0.0067003992 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.5965706431884413
# simulation started
# simulation ended
# error en simulacio:  0.44984453463009777
# simulation started
# simulation ended
# error en simulacio:  0.31328086106892794
# simulation started
# simulation ended
# error en simulacio:  0.06296479004764532
#     72 |      288 |  0.0067003992 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.9133920171659404
# simulation started
# simulation ended
# error en simulacio:  0.9698132768381156
# simulation started
# simulation ended
# error en simulacio:  0.9697965044964699
# simulation started
# simulation ended
# error en simulacio:  0.1113623101268919
#     73 |      292 |  0.0067003992 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.21519327003609845
# simulation started
# simulation ended
# error en simulacio:  0.6178068800115557
# simulation started
# simulation ended
# error en simulacio:  0.979952885890077
# simulation started
# simulation ended
# error en simulacio:  0.5429131974847156
#     74 |      296 |  0.0067003992 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.6881898080477126
# simulation started
# simulation ended
# error en simulacio:  0.6618344288753493
# simulation started
# simulation ended
# error en simulacio:  0.259085991853645
# simulation started
# simulation ended
# error en simulacio:  0.5416022629129655
#     75 |      300 |  0.0067003992 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.3073211178125135
# simulation started
# simulation ended
# error en simulacio:  0.24638119608509224
# simulation started
# simulation ended
# error en simulacio:  0.08136876538378779
# simulation started
# simulation ended
# error en simulacio:  0.2807867235646755
#     76 |      304 |  0.0067003992 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.9833767172194025
# simulation started
# simulation ended
# error en simulacio:  0.4479022405332955
# simulation started
# simulation ended
# error en simulacio:  0.6520105345126705
# simulation started
# simulation ended
# error en simulacio:  0.6434660802698416
#     77 |      308 |  0.0067003992 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.940734522249
# simulation started
# simulation ended
# error en simulacio:  0.39047855113892316
# simulation started
# simulation ended
# error en simulacio:  0.3067842948515136
# simulation started
# simulation ended
# error en simulacio:  0.3272414146871332
#     78 |      312 |  0.0067003992 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.3167351468856021
# simulation started
# simulation ended
# error en simulacio:  0.847134765826215
# simulation started
# simulation ended
# error en simulacio:  0.893500245521601
# simulation started
# simulation ended
# error en simulacio:  0.3028093296725163
#     79 |      316 |  0.0067003992 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.33433340565076186
# simulation started
# simulation ended
# error en simulacio:  0.5442254141821842
# simulation started
# simulation ended
# error en simulacio:  0.5789854363170839
# simulation started
# simulation ended
# error en simulacio:  0.5959625400010043
#     80 |      320 |  0.0067003992 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.2450980038952486
# simulation started
# simulation ended
# error en simulacio:  0.020374028446252357
# simulation started
# simulation ended
# error en simulacio:  0.24375929982791578
# simulation started
# simulation ended
# error en simulacio:  0.07232753387141089
#     81 |      324 |  0.0067003992 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.551204754915506
# simulation started
# simulation ended
# error en simulacio:  0.07091636753953445
# simulation started
# simulation ended
# error en simulacio:  0.07512979225452299
# simulation started
# simulation ended
# error en simulacio:  0.6353820935630572
#     82 |      328 |  0.0067003992 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.2908215504193956
# simulation started
# simulation ended
# error en simulacio:  0.7921847578822924
# simulation started
# simulation ended
# error en simulacio:  0.49326104275013793
# simulation started
# simulation ended
# error en simulacio:  0.8626489777797094
#     83 |      332 |  0.0067003992 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.15417959616284405
# simulation started
# simulation ended
# error en simulacio:  0.5014295859466933
# simulation started
# simulation ended
# error en simulacio:  0.794983493746024
# simulation started
# simulation ended
# error en simulacio:  0.0771069862639161
#     84 |      336 |  0.0067003992 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.9492279489729363
# simulation started
# simulation ended
# error en simulacio:  0.1732421083716036
# simulation started
# simulation ended
# error en simulacio:  0.7762089829859355
# simulation started
# simulation ended
# error en simulacio:  0.9848958711440725
#     85 |      340 |  0.0067003992 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.8215501447435144
# simulation started
# simulation ended
# error en simulacio:  0.3197840027930057
# simulation started
# simulation ended
# error en simulacio:  0.1068777345815598
# simulation started
# simulation ended
# error en simulacio:  0.5143582510552492
#     86 |      344 |  0.0067003992 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.919356939210688
# simulation started
# simulation ended
# error en simulacio:  0.29348949437066774
# simulation started
# simulation ended
# error en simulacio:  0.8937587976957898
# simulation started
# simulation ended
# error en simulacio:  0.14168064702669492
#     87 |      348 |  0.0067003992 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.9104816743927341
# simulation started
# simulation ended
# error en simulacio:  0.03175994589733666
# simulation started
# simulation ended
# error en simulacio:  0.3160686777608829
# simulation started
# simulation ended
# error en simulacio:  0.9030882837141124
#     88 |      352 |  0.0067003992 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.8038562809839719
# simulation started
# simulation ended
# error en simulacio:  0.9071537669967973
# simulation started
# simulation ended
# error en simulacio:  0.8407185222467378
# simulation started
# simulation ended
# error en simulacio:  0.7461848854045222
#     89 |      356 |  0.0067003992 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.6895951793002646
# simulation started
# simulation ended
# error en simulacio:  0.1781548656443236
# simulation started
# simulation ended
# error en simulacio:  0.43263800097623695
# simulation started
# simulation ended
# error en simulacio:  0.15789694375216057
#     90 |      360 |  0.0067003992 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.7148244519688113
# simulation started
# simulation ended
# error en simulacio:  0.667778739685542
# simulation started
# simulation ended
# error en simulacio:  0.2525864077938834
# simulation started
# simulation ended
# error en simulacio:  0.0644141933476613
#     91 |      364 |  0.0067003992 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.9633858833215757
# simulation started
# simulation ended
# error en simulacio:  0.8082526283723965
# simulation started
# simulation ended
# error en simulacio:  0.5492699313925192
# simulation started
# simulation ended
# error en simulacio:  0.5413776519849807
#     92 |      368 |  0.0067003992 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.8512926663313799
# simulation started
# simulation ended
# error en simulacio:  0.45330967762221785
# simulation started
# simulation ended
# error en simulacio:  0.39571044472076744
# simulation started
# simulation ended
# error en simulacio:  0.33866914489505884
#     93 |      372 |  0.0067003992 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.2579690924717717
# simulation started
# simulation ended
# error en simulacio:  0.024408502825104206
# simulation started
# simulation ended
# error en simulacio:  0.6464388440000969
# simulation started
# simulation ended
# error en simulacio:  0.4166838822984099
#     94 |      376 |  0.0067003992 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.5706036315777225
# simulation started
# simulation ended
# error en simulacio:  0.062321630803521044
# simulation started
# simulation ended
# error en simulacio:  0.3549434436862958
# simulation started
# simulation ended
# error en simulacio:  0.13828411395509788
#     95 |      380 |  0.0067003992 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.12512901528549036
# simulation started
# simulation ended
# error en simulacio:  0.259112968915828
# simulation started
# simulation ended
# error en simulacio:  0.8289343809851581
# simulation started
# simulation ended
# error en simulacio:  0.39779731306487276
#     96 |      384 |  0.0067003992 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.40108215192090135
# simulation started
# simulation ended
# error en simulacio:  0.612444922992939
# simulation started
# simulation ended
# error en simulacio:  0.23352965329584996
# simulation started
# simulation ended
# error en simulacio:  0.007477173042134244
#     97 |      388 |  0.0059431546 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.5287017398867132
# simulation started
# simulation ended
# error en simulacio:  0.5008996195572266
# simulation started
# simulation ended
# error en simulacio:  0.6488395923408533
# simulation started
# simulation ended
# error en simulacio:  0.4383169556417158
#     98 |      392 |  0.0059431546 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.6865131306582006
# simulation started
# simulation ended
# error en simulacio:  0.7314219491610718
# simulation started
# simulation ended
# error en simulacio:  0.23837467516202382
# simulation started
# simulation ended
# error en simulacio:  0.4950722507160109
#     99 |      396 |  0.0059431546 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.47882688758179337
# simulation started
# simulation ended
# error en simulacio:  0.225062085038767
# simulation started
# simulation ended
# error en simulacio:  0.4122461329173408
# simulation started
# simulation ended
# error en simulacio:  0.560407434487989
#    100 |      400 |  0.0059431546 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.9069395045058483
# simulation started
# simulation ended
# error en simulacio:  0.9177065838382222
# simulation started
# simulation ended
# error en simulacio:  0.27522536346579907
# simulation started
# simulation ended
# error en simulacio:  0.6464151756425885
#    101 |      404 |  0.0059431546 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.0481973433614038
# simulation started
# simulation ended
# error en simulacio:  0.07155138822789708
# simulation started
# simulation ended
# error en simulacio:  0.5116917092002066
# simulation started
# simulation ended
# error en simulacio:  0.877424078946487
#    102 |      408 |  0.0059431546 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.15946773075783105
# simulation started
# simulation ended
# error en simulacio:  0.7660278587973122
# simulation started
# simulation ended
# error en simulacio:  0.8830095693755464
# simulation started
# simulation ended
# error en simulacio:  0.3118020318353023
#    103 |      412 |  0.0059431546 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.6925569646028146
# simulation started
# simulation ended
# error en simulacio:  0.8489911224865752
# simulation started
# simulation ended
# error en simulacio:  0.3716143307475649
# simulation started
# simulation ended
# error en simulacio:  0.7012826629078087
#    104 |      416 |  0.0059431546 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.7364181165753182
# simulation started
# simulation ended
# error en simulacio:  0.5945778048409015
# simulation started
# simulation ended
# error en simulacio:  0.8562771389130047
# simulation started
# simulation ended
# error en simulacio:  0.8966043711163488
#    105 |      420 |  0.0059431546 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.9600788169648591
# simulation started
# simulation ended
# error en simulacio:  0.5712326942175455
# simulation started
# simulation ended
# error en simulacio:  0.17627589520647535
# simulation started
# simulation ended
# error en simulacio:  0.2505954088773793
#    106 |      424 |  0.0059431546 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.21761868850658306
# simulation started
# simulation ended
# error en simulacio:  0.5695173495977943
# simulation started
# simulation ended
# error en simulacio:  0.7577501146664367
# simulation started
# simulation ended
# error en simulacio:  0.05213322114218644
#    107 |      428 |  0.0059431546 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.6816364556074682
# simulation started
# simulation ended
# error en simulacio:  0.7171532633675107
# simulation started
# simulation ended
# error en simulacio:  0.3479815079568077
# simulation started
# simulation ended
# error en simulacio:  0.5150558042933419
#    108 |      432 |  0.0059431546 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.16479815203117487
# simulation started
# simulation ended
# error en simulacio:  0.7298961504869986
# simulation started
# simulation ended
# error en simulacio:  0.040708687336548866
# simulation started
# simulation ended
# error en simulacio:  0.981221058148159
#    109 |      436 |  0.0059431546 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.8079437334476703
# simulation started
# simulation ended
# error en simulacio:  0.6284485019821408
# simulation started
# simulation ended
# error en simulacio:  0.2675262446471117
# simulation started
# simulation ended
# error en simulacio:  0.9128628900924319
#    110 |      440 |  0.0059431546 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.9594388378770715
# simulation started
# simulation ended
# error en simulacio:  0.13912615902147096
# simulation started
# simulation ended
# error en simulacio:  0.7757572503157156
# simulation started
# simulation ended
# error en simulacio:  0.8419308585435238
#    111 |      444 |  0.0059431546 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.6597173563139825
# simulation started
# simulation ended
# error en simulacio:  0.7004077664167305
# simulation started
# simulation ended
# error en simulacio:  0.44505873211451163
# simulation started
# simulation ended
# error en simulacio:  0.9243078026249281
#    112 |      448 |  0.0059431546 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.9712075281962813
# simulation started
# simulation ended
# error en simulacio:  0.3823533128201745
# simulation started
# simulation ended
# error en simulacio:  0.8027115308003568
# simulation started
# simulation ended
# error en simulacio:  0.4329215913805363
#    113 |      452 |  0.0059431546 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.16475421868327378
# simulation started
# simulation ended
# error en simulacio:  0.32546727685726395
# simulation started
# simulation ended
# error en simulacio:  0.1263300748348425
# simulation started
# simulation ended
# error en simulacio:  0.9088847599027046
#    114 |      456 |  0.0059431546 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.9594240800441438
# simulation started
# simulation ended
# error en simulacio:  0.11918673240587485
# simulation started
# simulation ended
# error en simulacio:  0.6006790811870585
# simulation started
# simulation ended
# error en simulacio:  0.40822409770858314
#    115 |      460 |  0.0059431546 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.11809003100178916
# simulation started
# simulation ended
# error en simulacio:  0.295475514811817
# simulation started
# simulation ended
# error en simulacio:  0.2482163710806481
# simulation started
# simulation ended
# error en simulacio:  0.7495768111897567
#    116 |      464 |  0.0059431546 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.004008955954045934
# simulation started
# simulation ended
# error en simulacio:  0.18983870393308366
# simulation started
# simulation ended
# error en simulacio:  0.43877307011993694
# simulation started
# simulation ended
# error en simulacio:  0.02103467308587126
#    117 |      468 |  0.0048253279 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.6275265885374804
# simulation started
# simulation ended
# error en simulacio:  0.6056275385785042
# simulation started
# simulation ended
# error en simulacio:  0.8353323508828638
# simulation started
# simulation ended
# error en simulacio:  0.20660581568518466
#    118 |      472 |  0.0048253279 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.2847816135615888
# simulation started
# simulation ended
# error en simulacio:  0.5423394307527486
# simulation started
# simulation ended
# error en simulacio:  0.2732256972129319
# simulation started
# simulation ended
# error en simulacio:  0.585738083402959
#    119 |      476 |  0.0048253279 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.25088222945000915
# simulation started
# simulation ended
# error en simulacio:  0.6835271525859573
# simulation started
# simulation ended
# error en simulacio:  0.7910907183680019
# simulation started
# simulation ended
# error en simulacio:  0.8086546201638074
#    120 |      480 |  0.0048253279 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.9736161095498469
# simulation started
# simulation ended
# error en simulacio:  0.5453770038258688
# simulation started
# simulation ended
# error en simulacio:  0.49080927982901434
# simulation started
# simulation ended
# error en simulacio:  0.8556976997986436
#    121 |      484 |  0.0048253279 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.7690673858593793
# simulation started
# simulation ended
# error en simulacio:  0.5705446293870352
# simulation started
# simulation ended
# error en simulacio:  0.3832563847662638
# simulation started
# simulation ended
# error en simulacio:  0.2840474457335592
#    122 |      488 |  0.0048253279 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.10813920873416805
# simulation started
# simulation ended
# error en simulacio:  0.8075490893732804
# simulation started
# simulation ended
# error en simulacio:  0.11807153053066555
# simulation started
# simulation ended
# error en simulacio:  0.7472652346880435
#    123 |      492 |  0.0048253279 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.545287089768146
# simulation started
# simulation ended
# error en simulacio:  0.9649453287863279
# simulation started
# simulation ended
# error en simulacio:  0.7610656598531885
# simulation started
# simulation ended
# error en simulacio:  0.9735197845800538
#    124 |      496 |  0.0048253279 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.13659401293980755
# simulation started
# simulation ended
# error en simulacio:  0.5003714738318865
# simulation started
# simulation ended
# error en simulacio:  0.5725782871654547
# simulation started
# simulation ended
# error en simulacio:  0.3112514573124735
#    125 |      500 |  0.0048253279 |  0.0021060534
# simulation started
# simulation ended
# error en simulacio:  0.5030324882064976
# simulation started
# simulation ended
# error en simulacio:  0.35681876360334597
# simulation started
# simulation ended
# error en simulacio:  0.5283939713514435
# simulation started
# simulation ended
# error en simulacio:  0.0008447179488895173
#    126 |      504 |  0.0031672142 |  0.0008447179
# simulation started
# simulation ended
# error en simulacio:  0.4423143321124289
# simulation started
# simulation ended
# error en simulacio:  0.4495521437392589
# simulation started
# simulation ended
# error en simulacio:  0.3047991882212113
# simulation started
# simulation ended
# error en simulacio:  0.3994027475965406
#    127 |      508 |  0.0031672142 |  0.0008447179
# simulation started
# simulation ended
# error en simulacio:  0.7830873111719908
# simulation started
# simulation ended
# error en simulacio:  0.6834128839628029
# simulation started
# simulation ended
# error en simulacio:  0.4922991328917098
# simulation started
# simulation ended
# error en simulacio:  0.6476682418421831
#    128 |      512 |  0.0031672142 |  0.0008447179
# simulation started
# simulation ended
# error en simulacio:  0.377558211851013
# simulation started
# simulation ended
# error en simulacio:  0.20391405043667976
# simulation started
# simulation ended
# error en simulacio:  0.003875657877555727
# simulation started
# simulation ended
# error en simulacio:  0.27762125160942186
#    129 |      516 |  0.0027088463 |  0.0008447179
# simulation started
# simulation ended
# error en simulacio:  0.598164198713661
# simulation started
# simulation ended
# error en simulacio:  0.8816629330706961
# simulation started
# simulation ended
# error en simulacio:  0.8294212499885301
# simulation started
# simulation ended
# error en simulacio:  0.5109602078711931
#    130 |      520 |  0.0027088463 |  0.0008447179
# simulation started
# simulation ended
# error en simulacio:  0.987018145049427
# simulation started
# simulation ended
# error en simulacio:  0.46158097386980335
# simulation started
# simulation ended
# error en simulacio:  0.8345934861668383
# simulation started
# simulation ended
# error en simulacio:  0.4089653412809712
#    131 |      524 |  0.0027088463 |  0.0008447179
# simulation started
# simulation ended
# error en simulacio:  0.7446306177387316
# simulation started
# simulation ended
# error en simulacio:  0.9875916912226816
# simulation started
# simulation ended
# error en simulacio:  0.30533659236797617
# simulation started
# simulation ended
# error en simulacio:  0.17031282521328428
#    132 |      528 |  0.0027088463 |  0.0008447179
# simulation started
# simulation ended
# error en simulacio:  0.6200337087276608
# simulation started
# simulation ended
# error en simulacio:  0.5309561803740346
# simulation started
# simulation ended
# error en simulacio:  0.359422031985154
# simulation started
# simulation ended
# error en simulacio:  0.003519242097051234
#    133 |      532 |  0.0025864178 |  0.0008447179
# simulation started
# simulation ended
# error en simulacio:  0.3891626416098043
# simulation started
# simulation ended
# error en simulacio:  0.4258694721036601
# simulation started
# simulation ended
# error en simulacio:  0.405252071738319
# simulation started
# simulation ended
# error en simulacio:  0.8612453089775505
#    134 |      536 |  0.0025864178 |  0.0008447179
# simulation started
# simulation ended
# error en simulacio:  0.5844280270821319
# simulation started
# simulation ended
# error en simulacio:  0.7338307924531678
# simulation started
# simulation ended
# error en simulacio:  0.8979091716371104
# simulation started
# simulation ended
# ...
# simulation started
# simulation ended
# error en simulacio:  0.489220706738431
# simulation started
# simulation ended
# error en simulacio:  0.1249570386300286
# simulation started
# simulation ended
# error en simulacio:  0.8012474199612626
# simulation started
# simulation ended
# error en simulacio:  0.4516908525684106
#   3272 |    13088 |  0.0002373522 |  0.0002217059
# simulation started
# simulation ended
# error en simulacio:  0.19202776697548418
# simulation started
# simulation ended
# error en simulacio:  0.8722978302312447
# simulation started
# simulation ended
# error en simulacio:  0.9086471355187302
# simulation started
# simulation ended
# error en simulacio:  0.002681979628051945
#   3273 |    13092 |  0.0002373522 |  0.0002217059
# simulation started
# simulation ended
# error en simulacio:  0.5726496454119316
# simulation started
# simulation ended
# error en simulacio:  0.7840068703278411
# simulation started
# simulation ended
# error en simulacio:  0.16750350873413855
# simulation started
# simulation ended
# error en simulacio:  0.8802531547596608
#   3274 |    13096 |  0.0002373522 |  0.0002217059
# simulation started
# simulation ended
# error en simulacio:  0.8136501792644764
# simulation started
# simulation ended
# error en simulacio:  0.42692954939334304
# simulation started
# simulation ended
# error en simulacio:  0.9063825183634688
# simulation started
# simulation ended
# error en simulacio:  0.4997655331406736
#   3275 |    13100 |  0.0002373522 |  0.0002217059
# simulation started
# simulation ended
# error en simulacio:  0.21140950857888252
# simulation started
# simulation ended
# error en simulacio:  0.09707636255684127
# simulation started
# simulation ended
# error en simulacio:  0.7273937536609034
# simulation started
# simulation ended
# error en simulacio:  0.04571700630122899
#   3276 |    13104 |  0.0002373522 |  0.0002217059
# simulation started
# simulation ended
# error en simulacio:  0.35457245569286644
# simulation started
# simulation ended
# error en simulacio:  0.09231835802194688
# simulation started
# simulation ended
# error en simulacio:  0.5350209321862409
# simulation started
# simulation ended
# error en simulacio:  0.570771584771854
#   3277 |    13108 |  0.0002373522 |  0.0002217059
# simulation started
# simulation ended
# error en simulacio:  0.005746709920511073
# simulation started
# simulation ended
# error en simulacio:  0.902369514281261
# simulation started
# simulation ended
# error en simulacio:  0.09902913987582584
# simulation started
# simulation ended
# error en simulacio:  0.23104987715165526
#   3278 |    13112 |  0.0002373522 |  0.0002217059
# simulation started
# simulation ended
# error en simulacio:  0.03894171958479531
# simulation started
# simulation ended
# error en simulacio:  0.7103499393214576
# simulation started
# simulation ended
# error en simulacio:  0.41700201137921744
# simulation started
# simulation ended
# error en simulacio:  0.7426185202239712
#   3279 |    13116 |  0.0002373522 |  0.0002217059
# simulation started
# simulation ended
# error en simulacio:  0.151751953541988
# simulation started
# simulation ended
# error en simulacio:  0.3643868707768735
# simulation started
# simulation ended
# error en simulacio:  0.5173109792480728
# simulation started
# simulation ended
# error en simulacio:  0.7281882374945223
#   3280 |    13120 |  0.0002373522 |  0.0002217059
# simulation started
# simulation ended
# error en simulacio:  0.17963296735289713
# simulation started
# simulation ended
# error en simulacio:  0.26181407315562555
# simulation started
# simulation ended
# error en simulacio:  0.31698368040835234
# simulation started
# simulation ended
# error en simulacio:  0.37361383468346976
#   3281 |    13124 |  0.0002373522 |  0.0002217059
# simulation started
# simulation ended
# error en simulacio:  0.6536939521034515
# simulation started
# simulation ended
# error en simulacio:  0.6808593943976821
# simulation started
# simulation ended
# error en simulacio:  0.32600740658650096
# simulation started
# simulation ended
# error en simulacio:  0.87864903990375
#   3282 |    13128 |  0.0002373522 |  0.0002217059
# simulation started
# simulation ended
# error en simulacio:  0.680958113538998
# simulation started
# simulation ended
# error en simulacio:  0.11130482480738246
# simulation started
# simulation ended
# error en simulacio:  0.8161568208261349
# simulation started
# simulation ended
# error en simulacio:  0.9757579180822227
#   3283 |    13132 |  0.0002373522 |  0.0002217059
# simulation started
# simulation ended
# error en simulacio:  0.47458285751077545
# simulation started
# simulation ended
# error en simulacio:  0.9730426798955736
# simulation started
# simulation ended
# error en simulacio:  0.02179446023883369
# simulation started
# simulation ended
# error en simulacio:  0.339682166318512
#   3284 |    13136 |  0.0002373522 |  0.0002217059
# simulation started
# simulation ended
# error en simulacio:  0.10167838895364023
# simulation started
# simulation ended
# error en simulacio:  0.5653138299392962
# simulation started
# simulation ended
# error en simulacio:  0.8221629361614935
# simulation started
# simulation ended
# error en simulacio:  0.1500084412676047
#   3285 |    13140 |  0.0002373522 |  0.0002217059
# simulation started
# simulation ended
# error en simulacio:  0.05882060652239662
# simulation started
# simulation ended
# error en simulacio:  0.3096158913934094
# simulation started
# simulation ended
# error en simulacio:  0.8532720838848372
# simulation started
# simulation ended
# error en simulacio:  0.14935351098508354
#   3286 |    13144 |  0.0002373522 |  0.0002217059
# simulation started
# simulation ended
# error en simulacio:  0.484733431370994
# simulation started
# simulation ended
# error en simulacio:  0.6177066343438812
# simulation started
# simulation ended
# error en simulacio:  0.3455434094739519
# simulation started
# simulation ended
# error en simulacio:  0.7404268483401739
#   3287 |    13148 |  0.0002373522 |  0.0002217059
# simulation started
# simulation ended
# error en simulacio:  0.8136097217938666
# simulation started
# simulation ended
# error en simulacio:  0.03931086446923815
# simulation started
# simulation ended
# error en simulacio:  0.10200749897672157
# simulation started
# simulation ended
# error en simulacio:  0.8110996663925362
#   3288 |    13152 |  0.0002373522 |  0.0002217059
# simulation started
# simulation ended
# error en simulacio:  0.40740973873567454
# simulation started
# simulation ended
# error en simulacio:  0.8107772355103197
# simulation started
# simulation ended
# error en simulacio:  0.7126621293582042
# simulation started
# simulation ended
# error en simulacio:  0.8774109306349076
#   3289 |    13156 |  0.0002373522 |  0.0002217059
# simulation started
# simulation ended
# error en simulacio:  0.2097368089947098
# simulation started
# simulation ended
# error en simulacio:  0.20115183374677803
# simulation started
# simulation ended
# error en simulacio:  0.045235175877272105
# simulation started
# simulation ended
# error en simulacio:  0.05495626838482337
#   3290 |    13160 |  0.0002373522 |  0.0002217059
# simulation started
# simulation ended
# error en simulacio:  0.9419450927604225
# simulation started
# simulation ended
# error en simulacio:  0.5959231275023896
# simulation started
# simulation ended
# error en simulacio:  0.5272479930002061
# simulation started
# simulation ended
# error en simulacio:  0.5403119555193932
#   3291 |    13164 |  0.0002373522 |  0.0002217059
# simulation started
# simulation ended
# error en simulacio:  0.3851782719420578
# simulation started
# simulation ended
# error en simulacio:  0.5149480725758273
# simulation started
# simulation ended
# error en simulacio:  0.7607581157874831
# simulation started
# simulation ended
# error en simulacio:  0.09984372965667054
#   3292 |    13168 |  0.0002373522 |  0.0002217059
# simulation started
# simulation ended
# error en simulacio:  0.23082071090393685
# simulation started
# simulation ended
# error en simulacio:  0.29368530099980006
# simulation started
# simulation ended
# error en simulacio:  0.612218958510833
# simulation started
# simulation ended
# error en simulacio:  0.8511727999663786
#   3293 |    13172 |  0.0002373522 |  0.0002217059
# simulation started
# simulation ended
# error en simulacio:  0.4230424911858174
# simulation started
# simulation ended
# error en simulacio:  0.6777485451103076
# simulation started
# simulation ended
# error en simulacio:  0.046169700152860704
# simulation started
# simulation ended
# error en simulacio:  0.7289429613987357
#   3294 |    13176 |  0.0002373522 |  0.0002217059
# simulation started
# simulation ended
# error en simulacio:  0.9017867667231693
# simulation started
# simulation ended
# error en simulacio:  0.3316552229913682
# simulation started
# simulation ended
# error en simulacio:  0.12836516901166495
# simulation started
# simulation ended
# error en simulacio:  0.055920009217276245
#   3295 |    13180 |  0.0002373522 |  0.0002217059
# simulation started
# simulation ended
# error en simulacio:  0.09777703413460137
# simulation started
# simulation ended
# error en simulacio:  0.3238970829010184
# simulation started
# simulation ended
# error en simulacio:  0.4733928015786677
# simulation started
# simulation ended
# error en simulacio:  0.7759773123664545
#   3296 |    13184 |  0.0002373522 |  0.0002217059
# simulation started
# simulation ended
# error en simulacio:  0.6384808403729666
# simulation started
# simulation ended
# error en simulacio:  0.25331778955559925
# simulation started
# simulation ended
# error en simulacio:  0.4788968707021527
# simulation started
# simulation ended
# error en simulacio:  0.8942153402449143
#   3297 |    13188 |  0.0002373522 |  0.0002217059
# simulation started
# simulation ended
# error en simulacio:  0.18269070984982871
# simulation started
# simulation ended
# error en simulacio:  0.20881648876081838
# simulation started
# simulation ended
# error en simulacio:  0.16868513584675526
# simulation started
# simulation ended
# error en simulacio:  0.1518495103566403
#   3298 |    13192 |  0.0002373522 |  0.0002217059
# simulation started
# simulation ended
# error en simulacio:  0.6276593276312173
# simulation started
# simulation ended
# error en simulacio:  0.486228920156349
# simulation started
# simulation ended
# error en simulacio:  0.8966852657086014
# simulation started
# simulation ended
# error en simulacio:  0.8295382006138233
#   3299 |    13196 |  0.0002373522 |  0.0002217059
# simulation started
# simulation ended
# error en simulacio:  0.4944409450908449
# simulation started
# simulation ended
# error en simulacio:  0.15435370936943438
# simulation started
# simulation ended
# error en simulacio:  0.025737926068882477
# simulation started
# simulation ended
# error en simulacio:  0.05772817584198919
#   3300 |    13200 |  0.0002373522 |  0.0002217059
# simulation started
# simulation ended
# error en simulacio:  0.9635253178592749
# simulation started
# simulation ended
# error en simulacio:  0.4995579881966261
# simulation started
# simulation ended
# error en simulacio:  0.37177313282405666
# simulation started
# simulation ended
# error en simulacio:  0.5572247446500058
#   3301 |    13204 |  0.0002373522 |  0.0002217059
# simulation started
# simulation ended
# error en simulacio:  0.02896931438746342
# simulation started
# simulation ended
# error en simulacio:  0.541701785193958
# simulation started
# simulation ended
# error en simulacio:  0.5322860574396384
# simulation started
# simulation ended
# error en simulacio:  0.5915199048075327
#   3302 |    13208 |  0.0002373522 |  0.0002217059
# simulation started
# simulation ended
# error en simulacio:  0.2279229051377225
# simulation started
# simulation ended
# error en simulacio:  0.5814342985619715
# simulation started
# simulation ended
# error en simulacio:  0.042411103733490774
# simulation started
# simulation ended
# error en simulacio:  0.10180650719517592
#   3303 |    13212 |  0.0002373522 |  0.0002217059
# simulation started
# simulation ended
# error en simulacio:  0.3206438828316649
# simulation started
# simulation ended
# error en simulacio:  0.47636566490723575
# simulation started
# simulation ended
# error en simulacio:  0.4295347555236829
# simulation started
# simulation ended
# error en simulacio:  0.21189884856069297
#   3304 |    13216 |  0.0002373522 |  0.0002217059
# simulation started
# simulation ended
# error en simulacio:  0.13179842170025724
# simulation started
# simulation ended
# error en simulacio:  0.8020109528404534
# simulation started
# simulation ended
# error en simulacio:  0.18929374337817262
# simulation started
# simulation ended
# error en simulacio:  0.2706112267297267
#   3305 |    13220 |  0.0002373522 |  0.0002217059
# simulation started
# simulation ended
# error en simulacio:  0.9410629672895726
# simulation started
# simulation ended
# error en simulacio:  0.4562372437404639
# simulation started
# simulation ended
# error en simulacio:  0.9529791049303329
# simulation started
# simulation ended
# error en simulacio:  0.6534171177320383
#   3306 |    13224 |  0.0002373522 |  0.0002217059
# simulation started
# simulation ended
# error en simulacio:  0.3735612343661441
# simulation started
# simulation ended
# error en simulacio:  0.4979902786265267
# simulation started
# simulation ended
# error en simulacio:  0.32631963817802456
# simulation started
# simulation ended
# error en simulacio:  0.7519638191757663
#   3307 |    13228 |  0.0002373522 |  0.0002217059
# simulation started
# simulation ended
# error en simulacio:  0.00022145178278898392
# simulation started
# simulation ended
# error en simulacio:  0.18593858803989893
# simulation started
# simulation ended
# error en simulacio:  0.03982628524124243
# simulation started
# simulation ended
# error en simulacio:  0.6592012932909942
#   3308 |    13232 |  0.0002292556 |  0.0002214518
# simulation started
# simulation ended
# error en simulacio:  0.10712607528407514
# simulation started
# simulation ended
# error en simulacio:  0.14895689797448064
# simulation started
# simulation ended
# error en simulacio:  0.3255416742011955
# simulation started
# simulation ended
# error en simulacio:  0.28449182689261976
#   3309 |    13236 |  0.0002292556 |  0.0002214518
# simulation started
# simulation ended
# error en simulacio:  0.5628835422135601
# simulation started
# simulation ended
# error en simulacio:  0.1592435276873322
# simulation started
# simulation ended
# error en simulacio:  0.9206798803768277
# simulation started
# simulation ended
# error en simulacio:  0.4220829982647587
#   3310 |    13240 |  0.0002292556 |  0.0002214518
# simulation started
# simulation ended
# error en simulacio:  0.18647683141618232
# simulation started
# simulation ended
# error en simulacio:  0.8682951191933204
# simulation started
# simulation ended
# error en simulacio:  0.9631324437142817
# simulation started
# simulation ended
# error en simulacio:  0.7367756958385662
#   3311 |    13244 |  0.0002292556 |  0.0002214518
# simulation started
# simulation ended
# error en simulacio:  0.11205274157761813
# simulation started
# simulation ended
# error en simulacio:  0.42100881032578086
# simulation started
# simulation ended
# error en simulacio:  0.9371022804986633
# simulation started
# simulation ended
# error en simulacio:  0.2838867051805657
#   3312 |    13248 |  0.0002292556 |  0.0002214518
# simulation started
# simulation ended
# error en simulacio:  0.3379531934328067
# simulation started
# simulation ended
# error en simulacio:  0.1744725882665178
# simulation started
# simulation ended
# error en simulacio:  0.2656422143800642
# simulation started
# simulation ended
# error en simulacio:  0.40700757672498644
#   3313 |    13252 |  0.0002292556 |  0.0002214518
# simulation started
# simulation ended
# error en simulacio:  0.21943242395449103
# simulation started
# simulation ended
# error en simulacio:  0.5783254075260649
# simulation started
# simulation ended
# error en simulacio:  0.13111154469335629
# simulation started
# simulation ended
# error en simulacio:  0.06952329426212689
#   3314 |    13256 |  0.0002292556 |  0.0002214518
# simulation started
# simulation ended
# error en simulacio:  0.3501740069599405
# simulation started
# simulation ended
# error en simulacio:  0.8674888418551648
# simulation started
# simulation ended
# error en simulacio:  0.8693813451403439
# simulation started
# simulation ended
# error en simulacio:  0.49241947524903884
#   3315 |    13260 |  0.0002292556 |  0.0002214518
# simulation started
# simulation ended
# error en simulacio:  0.7779213529725311
# simulation started
# simulation ended
# error en simulacio:  0.7936009042430279
# simulation started
# simulation ended
# error en simulacio:  0.66123342933156
# simulation started
# simulation ended
# error en simulacio:  0.8562167710051656
#   3316 |    13264 |  0.0002292556 |  0.0002214518

# %%
res
# Out:
# {'best_params': {'solub': 198.4392600284095,
#   'aq_hlife': 52.034491104988234,
#   'aq_volat': 1.2173915570602744e-05,
#   'mol_wt': 300.7879648748127,
#   'aq_resus': 0.0024036667027493644,
#   'aq_settle': 0.6127819433765586,
#   'ben_act_dep': 0.37676341902399035,
#   'ben_bury': 0.0026088453764971926,
#   'ben_hlife': 49.09684326547141,
#   'kow': 636.8892525398122},
#  'best_error': 0.00022145178278898392}
