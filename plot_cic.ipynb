# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from src.SWATPollution import SWATPollution
from pathlib import Path
from src.pollution_utils import generate_pollution_observations, observacions_from_conca
import pandas as pd

# %%
contaminant = 'Triclorometà'
conca = 'sud'

# %%
cwd = Path('C:\\Users\\jsalo\\Desktop\\ICRA\\pyswat')
txtinout_folder = cwd/'data'/'txtinouts'/'tmp'/contaminant/conca
channels_geom_path = cwd/'data'/'rivs1'/'canals_tot_ci.shp'
lod_path = cwd / 'data' / 'lod.xlsx'

# %%
observacions = generate_pollution_observations(contaminant)
df = observacions_from_conca(channels_geom_path, observacions, conca)

# %%
first_observation = df.year.min()
year_end = 2022
year_start = max(first_observation-3, 2000) #3 years warm-up
warmup = max(1, first_observation - year_start)

# %%
lod_df = pd.read_excel(lod_path, index_col=0)
lod = lod_df.loc[contaminant, 'LOD (mg/L)']

# %%
"""
swatpy = SWATPollution( 
        conca, 
        contaminant, 
        txtinout_folder = cwd/'data'/'txtinouts'/f"TxtInOut_{conca}",
        channels_geom_path = cwd/'data'/'rivs1'/'canals_tot_ci.shp',
        tmp_path = cwd/'data'/'txtinouts'/'tmp'/conca,
        run = True,
        compound_features = {},
        show_output = True,
        copy_txtinout=True,
        overwrite_txtinout=True
    )


"""
swatpy = SWATPollution( 
        conca, 
        contaminant, 
        txtinout_folder = txtinout_folder,
        channels_geom_path = channels_geom_path,
        run = False,
        observacions = observacions.copy(),
        lod = lod,
        year_start = year_start,
        year_end = year_end,
        warmup = warmup
)

# %%
#rmse
swatpy.get_error()
# Out:
# -0.09063045153576899

# %%
swatpy.simple_map()
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Path.I   :Path   [Longitude,Latitude]   (LINKNO,Channel,ChannelR,Subbasin,AreaC,strmOrder,Len2,Slo2,Wid2,Dep2,MinEl,MaxEl,Reservoir,Pond,LakeIn,LakeOut,layer)
#    .Points.I :Points   [Longitude,Latitude]   (valor,mg_l,error,max_error)

# %%
swatpy.visualise_load()
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# c:\Users\jsalo\Desktop\ICRA\pyswat\plot_cic.ipynb Cell 11 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/jsalo/Desktop/ICRA/pyswat/plot_cic.ipynb#X42sZmlsZQ%3D%3D?line=0'>1</a> swatpy.visualise_load()
#
# File c:\Users\jsalo\Desktop\ICRA\pyswat\src\SWATPollution.py:351, in SWATPollution.visualise_load(self, day, month, year)
#     350 def visualise_load(self, day = 1, month = 1, year = 2001):
# --> 351     return self.visualise_map('tot_out_mg', 'load', 'mg/day', day, month, year)
#
# File c:\Users\jsalo\Desktop\ICRA\pyswat\src\SWATPollution.py:323, in SWATPollution.visualise_map(self, attribute, name, units, day, month, year)
#     320 gdf_map = self.gdf_map[(self.gdf_map['Date'].dt.year == year) & (self.gdf_map['Date'].dt.month == month) & (self.gdf_map['Date'].dt.day == day)]
#     322 if (len(gdf_map) == 0):
# --> 323     raise Exception("No data for this date")
#     325 gdf_map = gdf_map.copy()
#     327 #apply sqrt scale
#
# Exception: No data for this date

# %%
swatpy.visualise_concentration()
# Out:
# :Overlay
#    .Path.I  :Path   [Longitude,Latitude]   (month,day,year,gis_id,pollutant,mg_l,flo_out,tot_out_mg,Channel,layer,Date,date_str,color)
#    .Path.II :Path   [Longitude,Latitude]   (month,day,year,gis_id,pollutant,mg_l,flo_out,tot_out_mg,Channel,layer,Date,date_str,color)
#    .WMTS.I  :WMTS   [Longitude,Latitude]

# %%
swatpy.scatter_plot()
