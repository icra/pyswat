# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from src.IHA import IHA
import pandas as pd
#import pymannkendall as mk
import numpy as np
from pySWATPlus.TxtinoutReader import TxtinoutReader

# %%
#txtinout_folder = 'C:\\Users\\jsalo\\Desktop\\a'

txtinout_folder = 'C:\\Users\\jsalo\\Desktop\\ICRA\\pyswat\\data\\txtinouts\\tmp\\Diuron\\fluvia'
filename =  'plants.plt'

# %%
reader = TxtinoutReader(txtinout_folder)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 reader = TxtinoutReader(txtinout_folder)
#
# NameError: name 'TxtinoutReader' is not defined

# %%
plants_reader = reader.register_file(filename, 
                    has_units=False,
                    index='name')

# %%
plants_reader.header_file
# Out:
# 'plants.plt: written by SWAT+ editor v2.2.0 on 2023-03-02 13:02 for SWAT+ rev.60.5.4\n'

# %%
plants_reader.df
# Out:
#             name     plnt_typ  ... wnd_flat                    description
#                                ...
# agrc        agrc  cold_annual  ...      0.0  agricultural_land_close_grown
# agrl        agrl  warm_annual  ...      0.0      agricultural_land_generic
# agrr        agrr  warm_annual  ...      0.0          agricultural_land_row
# alfa        alfa    perennial  ...      0.0                        alfalfa
# almd        almd    perennial  ...      0.0                         almond
# ...          ...          ...  ...      ...                            ...
# wwht150  wwht150  cold_annual  ...      0.0         winter_wheat irrigated
# wwht160  wwht160  cold_annual  ...      0.0                   winter_wheat
# wwht170  wwht170  cold_annual  ...      0.0                   winter_wheat
# wetw        wetw    perennial  ...      0.0                    wetland_wet
# wetm        wetm    perennial  ...      0.0                  wetland_mixed
#
# [261 rows x 54 columns]

# %%
params  = {
    'plants.plt': ('name', [('agrc', 'nfix_co', 10)])
}

results = {
    'hru_pw_aa.txt':  ['jday', 'mon', 'day', 'yr', 'unit', 'name', 'lai', 'bioms', 'yield', 'residue'],
    'hru_wb_aa.txt':  ['jday', 'mon', 'day', 'yr', 'unit', 'name', 'wateryld', 'surq_gen', 'eplant', 'et']
}

#results = reader.run_swat(params, results)

# %%
params  = [
    {'plants.plt': ('name', [('agrc', 'nfix_co', 10)])},
    {'plants.plt': ('name', [('agrc', 'nfix_co', 30)])}
    ]


results = {
    'hru_pw_aa.txt':  ['jday', 'mon', 'day', 'yr', 'unit', 'name', 'lai', 'bioms', 'yield', 'residue'],
    'hru_wb_aa.txt':  ['jday', 'mon', 'day', 'yr', 'unit', 'name', 'wateryld', 'surq_gen', 'eplant', 'et']
}
#results = reader.run_parallel_swat(params, results)

# %%
#try optimization
observations_df = reader.register_file('hru_pw_aa.txt', 
                    has_units=True).df

observations_df = observations_df[['jday', 'mon', 'day', 'yr', 'unit', 'lai']]
observations_df
# Out:
#        jday  mon  day    yr   unit    lai
# 0       365   12   31  2003      1  0.668
# 1       365   12   31  2003      2  0.668
# 2       365   12   31  2003      3  0.668
# 3       365   12   31  2003      4  0.667
# 4       365   12   31  2003      5  0.668
# ...     ...  ...  ...   ...    ...    ...
# 13957   365   12   31  2003  13958  0.000
# 13958   365   12   31  2003  13959  0.000
# 13959   365   12   31  2003  13960  0.000
# 13960   365   12   31  2003  13961  0.000
# 13961   365   12   31  2003  13962  0.000
#
# [13962 rows x 6 columns]

# %%
params_file = 'plants.plt'
params_index = 'name'
params_id = 'agrc'
params = [('nfix_co', 1000, 0)]

result_file = 'hru_pw_aa.txt'
result_id_columns = ['jday', 'mon', 'day', 'yr', 'unit']
result_optimization_column = 'lai'

reader.single_optimization(params_file, params_index, params_id, params, result_file, result_id_columns, result_optimization_column, observations_df, 'rmse')
# Out:
# Threads: 3.9024457931518555

# %%
df.lai_pred.values
# Out:
# array([0.668, 0.668, 0.668, ..., 0.   , 0.   , 0.   ])

# %%
#Select columns where their unit value is 209
df = df[df['unit'] == 204]

df

# %%
df_2001 = df[df['Date'].dt.year == 2001]
df_2001

# %%
#df = pd.read_csv("C:\\Users\\ollorente\\Documents\\ICRA\\IHA\\DadesLaia\\channel_sdmorph_day.csv")

# %%
a_47_df = pd.read_csv("Observations/a47.csv")
a_47_df['Date'] = pd.to_datetime(a_47_df['Date'])

a_47_df

# %%
a_03_df = pd.read_csv("Observations/a03.csv")
#parse date column
a_03_df['Date'] = pd.to_datetime(a_03_df['Date'])
a_03_df

# %%
a_03 = IHA(a_03_df, date_col = 'Date', flow_col = 'Flow')

# %%
a_47 = IHA(a_47_df, date_col = 'Date', flow_col = 'Flow')

# %%
data = IHA(df, date_col = 'Date', flow_col = 'Flow')

# %%
data.year_month_median()

# %%
df_unit

# %%
data.perccntage_dry_river_network(df_unit)

# %%
data.annual_1_day_minima()

# %%
data.annual_1_day_maxima()

# %%
data.annual_7_day_minima()

# %%
data.annual_7_day_maxima()

# %%
data.annual_90_day_minima()

# %%
data.annual_90_day_maxima()

# %%
data.zero_flow_days()

# %%
data.annual_1_day_min_julian_day()

# %%
data.annual_1_day_max_julian_day()

# %%
data.high_pulses_per_year()

# %%
data.low_pulses_per_year()

# %%
data.mean_duration_high_pulses()

# %%
data.mean_duration_low_pulses()

# %%
data.mean_of_pos_inc_cons_flows()

# %%
data.median_of_pos_inc_cons_flows()

# %%
data.mean_of_neg_inc_cons_flows()

# %%
data.median_of_neg_inc_cons_flows()

# %%
data.num_flow_reversals()

# %%
a_47.annual_1_day_minima()

# %%
a_47.annual_1_day_min_julian_day()

# %%
a_47.num_flow_reversals()

# %%
data.freq_zero_flow_periods()

# %%
data.mean_zero_flow_periods()

# %%
data.zero_flow_onset()

# %%
data.zero_flow_central_point()

# %%
mk.original_test(a_03_df.Flow)

# %%
x = np.random.rand(1000,5)  # here consider 5 station/location where every station have 1000 data
mk.regional_test(x,0.05)
